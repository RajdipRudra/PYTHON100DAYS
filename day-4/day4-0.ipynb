# %% [markdown]
# <h1>DAY-4<br>RANDOMISATION AND PYTHON LISTS</h1>

# %% [markdown]
# <b>HOW TO IMPORT A MODULE

# %%
#we have to use the import keyword and the file name then the specific module from that file such as--->>>
import mytest
print(f"The value of pi is --> {mytest.pi}")
print(mytest.a - mytest.b)
# Out:
# The value of pi is --> 3.14159265
# 5000

# %% [markdown]
# <h4>RANDOM</h4>

# %%
#first we need to import the random module in our code by using the import keyword
import random as rn 
print(rn.randint(10,90))
# Out:
# 32

# %%
print(f"This gives uss the floating point number from 0 to 0.9999999999999999999 but ont 1 :\n{rn.random()*5}")
# Out:
# This gives uss the floating point number from 0 to 0.9999999999999999999 but ont 1 :
# 4.009131834982417

# %% [markdown]
# LOVE CALCULATOR

# %%
person1 = input("enter your name-->")
person2 = input("enter your partner's name-->")

print(f"Your love score is {rn.randint(1,100)} !")
# Out:
# Your love score is 76 !

# %% [markdown]
# HEADS OR TAILS

# %%
test_seed = int(input("creat a seed number: "))
rn.seed(test_seed)

result = rn.choice(["HEAD", "TAIL"])

print(result)
# Out:
# HEAD

# %% [markdown]
# <h4><b>LISTS</h4>

# %% [markdown]
# access items fro the lists

# %%
usa_states_by_admission = [
    "Delaware",
    "Pennsylvania",
    "New Jersey",
    "Georgia",
    "Connecticut",
    "Massachusetts",
    "Maryland",
    "South Carolina",
    "New Hampshire",
    "Virginia",
    "New York",
    "North Carolina",
    "Rhode Island",
    "Vermont",
    "Kentucky",
    "Tennessee",
    "Ohio",
    "Louisiana",
    "Indiana",
    "Mississippi",
    "Illinois",
    "Alabama",
    "Maine",
    "Missouri",
    "Arkansas",
    "Michigan",
    "Florida",
    "Texas",
    "Iowa",
    "Wisconsin",
    "California",
    "Minnesota",
    "Oregon",
    "Kansas",
    "West Virginia",
    "Nevada",
    "Nebraska",
    "Colorado",
    "North Dakota",
    "South Dakota",
    "Montana",
    "Washington",
    "Idaho",
    "Wyoming",
    "Utah",
    "Oklahoma",
    "New Mexico",
    "Arizona",
    "Alaska",
    "Hawaii"
]

print(f"0 no index : {usa_states_by_admission[0]}\n")
print(f"len/2 to last-->\n{usa_states_by_admission[round(len(usa_states_by_admission)/2):]}\n")


print(f"-1-->{usa_states_by_admission[-1 ]}\n")

print(f"(len/2)-5 to -1 -->\n{usa_states_by_admission[-round(len(usa_states_by_admission)/2-5):-1]}\n")

print(f"reverse-->\n{usa_states_by_admission[::-1]}\n")
# Out:
# 0 no index : Delaware
#
# len/2 to last-->
# ['Michigan', 'Florida', 'Texas', 'Iowa', 'Wisconsin', 'California', 'Minnesota', 'Oregon', 'Kansas', 'West Virginia', 'Nevada', 'Nebraska', 'Colorado', 'North Dakota', 'South Dakota', 'Montana', 'Washington', 'Idaho', 'Wyoming', 'Utah', 'Oklahoma', 'New Mexico', 'Arizona', 'Alaska', 'Hawaii']
#
# -1-->Hawaii
#
# (len/2)-5 to -1 -->
# ['California', 'Minnesota', 'Oregon', 'Kansas', 'West Virginia', 'Nevada', 'Nebraska', 'Colorado', 'North Dakota', 'South Dakota', 'Montana', 'Washington', 'Idaho', 'Wyoming', 'Utah', 'Oklahoma', 'New Mexico', 'Arizona', 'Alaska']
#
# reverse-->
# ...

# %% [markdown]
# ways to edit values in a list

# %%
usa_states_by_admission[-2] = "RAJALANDD" #assinning values to a list by the index rewrites the privious value 
print(usa_states_by_admission[40:])
# Out:
# ['Montana', 'Washington', 'Idaho', 'Wyoming', 'Utah', 'Oklahoma', 'New Mexico', 'Arizona', 'RAJALANDD', 'Hawaii']

# %%
usa_states_by_admission.append("JOYLANDDDD")#append method adds an item/value at the end of a list
print(usa_states_by_admission[40:])
# Out:
# ['Montana', 'Washington', 'Idaho', 'Wyoming', 'Utah', 'Oklahoma', 'New Mexico', 'Arizona', 'RAJALANDD', 'Hawaii', 'JOYLANDDDD']

# %%
usa_states_by_admission.extend(["BABALAND","MALAND","DADULAND"])#extend method adds an multiple item/value or LISTS at the end of a list to extend it!
print(usa_states_by_admission[40:])
# Out:
# ['Montana', 'Washington', 'Idaho', 'Wyoming', 'Utah', 'Oklahoma', 'New Mexico', 'Arizona', 'RAJALANDD', 'Hawaii', 'JOYLANDDDD', 'BABALAND', 'MALAND', 'DADULAND', 'BABALAND', 'MALAND', 'DADULAND']

# %% [markdown]
# <B><I>EXERSIZEEEEEEE

# %%
# test_seeddd = int(input("Create a seed number: "))
# rn.seed(test_seeddd)

namesASCSV = input("Give me everybody's names, separated by space").lower().split()
for i in range(11):

    gonna_pay = rn.choice(namesASCSV)

    print(f"TODAYS GONNA PAY {gonna_pay}")
# Out:
# TODAYS GONNA PAY joy
# TODAYS GONNA PAY lima
# TODAYS GONNA PAY prionty
# TODAYS GONNA PAY lima
# TODAYS GONNA PAY prionty
# TODAYS GONNA PAY prionty
# TODAYS GONNA PAY dip
# TODAYS GONNA PAY sreyyya
# TODAYS GONNA PAY prionty
# TODAYS GONNA PAY raj
# TODAYS GONNA PAY prionty

# %% [markdown]
# TRESURE MAP DAY4.3 EXERSIZEE

# %%
import os
row1 = ['⬜️', '⬜️', '⬜️']
row2 = ['⬜️', '⬜️', '⬜️']
row3 = ['⬜️', '⬜️', '⬜️']

map =[row1,row2,row3]

stop =0

while stop==0:
    print(f"{row1}\n{row2}\n{row3}\n")
    user_input = input("first enter the column , and then row-->")
    try:
        column = int(user_input[0])#2
        row = int(user_input[1])#3

        map[row-1][column-1] = "💰"
        print(f"{row1}\n{row2}\n{row3}\n")
        os.system('clear')
    except IndexError:
        stop=1
# Out:
# ['⬜️', '⬜️', '⬜️']
# ['⬜️', '⬜️', '⬜️']
# ['⬜️', '⬜️', '⬜️']
#
# ['⬜️', '⬜️', '⬜️']
# ['⬜️', '💰', '⬜️']
# ['⬜️', '⬜️', '⬜️']
#
# ['⬜️', '⬜️', '⬜️']
# ['⬜️', '💰', '⬜️']
# ['⬜️', '⬜️', '⬜️']

# %% [markdown]
# ROCK PAPER SISSOR GAMEEE

# %%
rock = '''
    _______
---'   ____)
      (_____)
      (_____)
      (____)
---.__(___)
'''

paper = '''
    _______
---'   ____)____
          ______)
          _______)
         _______)
---.__________)
'''

scissors = '''
    _______
---'   ____)____
          ______)
       __________)
      (____)
---.__(___)
'''



asciii = [rock,paper,scissors]

user_input_ = int(input("enter 0 for rock, 1 for paper and 2 for scissors"))
print(asciii[user_input_])

computer = rn.randint(0,2)
print(asciii[computer])

if (user_input_== computer):
    print("IT'S A TIEE")
elif (user_input_== 0 and computer==2) or (user_input_==1 and computer==0) or (user_input_==2 and computer==1):
    print("YOU WINN")


elif (user_input_== 2 and computer==0) or (user_input_==0 and computer==1) or (user_input_==1 and computer==2):
    print("YOU LOSE")
# Out:
#     _______
# ---'   ____)____
#           ______)
#           _______)
#          _______)
# ---.__________)
#
#
#     _______
# ---'   ____)
#       (_____)
#       (_____)
#       (____)
# ---.__(___)
#
# YOU WINN
