# %% [markdown]
# <h1 align='center'>TEST!!!</h1>

# %% [markdown]
# <div align='center'>
# <img  src="Screenshot from 2025-12-05 02-11-06.png" width="500" height="600">
# </div>

# %% [markdown]
# <h3>1 no problem

# %%
for i in range(10):
    print("*"*i)
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********

# %%
for i in range(10,0,-1):
    print("*"*(i))
# Out:
# **********
# *********
# ********
# *******
# ******
# *****
# ****
# ***
# **
# *

# %%
len = 15
j = 1
for i in range(len,0,-1):
    print(" "*(i),"*"*j)
    j+= 1
# Out:
#                 *
#                **
#               ***
#              ****
#             *****
#            ******
#           *******
#          ********
#         *********
#        **********
#       ***********
#      ************
#     *************
#    **************
#   ***************

# %% [markdown]
# my best try witout ai

# %%
joo = 10
j = 1
for i in range(joo,0,-1):
    print(" "*int(i/2),"*"*int(j))
    j+= 1
# Out:
#       *
#      **
#      ***
#     ****
#     *****
#    ******
#    *******
#   ********
#   *********
#  **********

# %%
joo = 10
j = 1
for i in range(joo,0,-1):
    print(" "*int(i/2),"*"*int(j))
    j+= 1
print()
joo = 10
j = joo
for i in range(joo,0,-1):
    print("0"*int(joo-j),"*"*int(j))
    j-= 1
# Out:
#       *
#      **
#      ***
#     ****
#     *****
#    ******
#    *******
#   ********
#   *********
#  **********
#
#  **********
# 0 *********
# 00 ********
# 000 *******
# 0000 ******
# 00000 *****
# 000000 ****
# 0000000 ***
# 00000000 **
# 000000000 *

# %% [markdown]
# ai

# %%
# def hollow_pyramid(n):
#     for i in range(1, n + 1):
#         for j in range(1, 2 * n):
#             # Logic to print stars or spaces based on row and position
#             if j == n - i + 1 or j == n + i - 1 or i == n:
#                 print("*", end="")
#             else:
#                 print(" ", end="")
#         print() # Move to the next line

# hollow_pyramid(5)

# %%
for i in range(1, 10 + 1):
    for j in range(10 - i):
        print(" ", end="")

    for k in range(2 * i - 1):
        print("*", end="")
    print()
# Out:
#          *
#         ***
#        *****
#       *******
#      *********
#     ***********
#    *************
#   ***************
#  *****************
# *******************

# %%
boaal = 10

for i in range(1,10+1):
    for j in range(10-i):
        print(" ", end="")
    for k in range(2*i-1):
        print("*",end="")
    print()

for i in range(10,0,-1):
    for j in range(10-i):
        print(" ", end="")
    for k in range(2*i-1):
        print("*",end="")
    print()
# Out:
#          *
#         ***
#        *****
#       *******
#      *********
#     ***********
#    *************
#   ***************
#  *****************
# *******************
# *******************
#  *****************
#   ***************
#    *************
#     ***********
#      *********
#       *******
#        *****
#         ***
#          *

# %%
rows = 10  # this will control the top half

# total height = top half + middle + bottom half
total_rows = rows * 2 + 1

j = 1  # start stars
direction = 1  # 1 = growing, -1 = shrinking

for i in range(total_rows):
    # print spaces
    print("_" * (rows - j + 1) + "*" * (2 * j - 1))
    
    # change direction at the widest point
    if j == rows + 1:
        direction = -1
    j += direction
# Out:
# __________*
# _________***
# ________*****
# _______*******
# ______*********
# _____***********
# ____*************
# ___***************
# __*****************
# _*******************
# *********************
# _*******************
# __*****************
# ___***************
# ____*************
# _____***********
# ______*********
# _______*******
# ________*****
# _________***
# __________*

# %% [markdown]
# <h3>no2.PALENDROM

# %%
STRING = 'ILOVEU'
list(STRING)
# Out:
# ['I', 'L', 'O', 'V', 'E', 'U']

# %%
# user_input = list(input("enter a letter to check if it's palendrom or not\n").lower())

user_input = ["aba","abba","ada","aga","aha","aka","ala","alula","ana",
    "anna","ara","asa","ava","bib","bob","boob","bub","civic","dad",
    "deed","deified","did","dud","eke","ere","esse","eve","ewe","eye",
    "gag","gig","kayak","kazak","keek","kook","laval","level","madam","malayalam",
    "mam","mim","minim","mom","mum","nan","naan","non","noon","nun",
    "otto","pip","pop","poop","pup","radar","redder","refer","repaper","reviver",
    "rotator","rotor","sagas","sees","sexes","sis","solos","sos","stats","stets",
    "tenet","terret","tit","toot","tot","tut","ulu","utu","wow","mm",
    "adaada","ekeeke","kazak","mum","pep","pop","pup","rar","rarar","ror",
    "roror","sas","sasas","sus","susus","tat","tattarrattat","eveeve","ekeeke","annaanna",
    "hannah","ottootto","noonnoon","bobobo","deedede","gigig","nununu","peep","wowow","mumum"
]

"nununu", "deedede","bobobo"

for i in user_input:
    user_inputtt = list(i)
    # indexx = user_input.index(i)
    reverse_list = user_inputtt[::-1]

    if user_inputtt==reverse_list:
        print(f"the word {"".join(user_inputtt)} is palendrom \n")
    else:
        print("not")
# Out:
# the word aba is palendrom
#
# the word abba is palendrom
#
# the word ada is palendrom
#
# the word aga is palendrom
#
# the word aha is palendrom
#
# the word aka is palendrom
#
# the word ala is palendrom
#
# the word alula is palendrom
#
# the word ana is palendrom
#
# the word anna is palendrom
#
# the word ara is palendrom
#
# the word asa is palendrom
#
# the word ava is palendrom
#
# the word bib is palendrom
#
# the word bob is palendrom
#
# the word boob is palendrom
#
# the word bub is palendrom
#
# the word civic is palendrom
#
# the word dad is palendrom
#
# the word deed is palendrom
#
# the word deified is palendrom
#
# the word did is palendrom
#
# the word dud is palendrom
#
# the word eke is palendrom
#
# the word ere is palendrom
#
# the word esse is palendrom
#
# the word eve is palendrom
#
# the word ewe is palendrom
#
# the word eye is palendrom
#
# the word gag is palendrom
#
# the word gig is palendrom
#
# the word kayak is palendrom
#
# the word kazak is palendrom
#
# the word keek is palendrom
#
# the word kook is palendrom
#
# the word laval is palendrom
#
# the word level is palendrom
#
# the word madam is palendrom
#
# the word malayalam is palendrom
#
# the word mam is palendrom
#
# the word mim is palendrom
#
# the word minim is palendrom
#
# the word mom is palendrom
#
# the word mum is palendrom
#
# the word nan is palendrom
#
# the word naan is palendrom
#
# the word non is palendrom
#
# the word noon is palendrom
#
# the word nun is palendrom
#
# the word otto is palendrom
#
# the word pip is palendrom
#
# the word pop is palendrom
#
# the word poop is palendrom
#
# the word pup is palendrom
#
# the word radar is palendrom
#
# the word redder is palendrom
#
# the word refer is palendrom
#
# the word repaper is palendrom
#
# the word reviver is palendrom
#
# the word rotator is palendrom
#
# the word rotor is palendrom
#
# the word sagas is palendrom
#
# the word sees is palendrom
#
# the word sexes is palendrom
#
# the word sis is palendrom
#
# the word solos is palendrom
#
# the word sos is palendrom
#
# the word stats is palendrom
#
# the word stets is palendrom
#
# the word tenet is palendrom
#
# the word terret is palendrom
#
# the word tit is palendrom
#
# the word toot is palendrom
#
# the word tot is palendrom
#
# the word tut is palendrom
#
# the word ulu is palendrom
#
# the word utu is palendrom
#
# the word wow is palendrom
#
# the word mm is palendrom
#
# the word adaada is palendrom
#
# the word ekeeke is palendrom
#
# the word kazak is palendrom
#
# the word mum is palendrom
#
# the word pep is palendrom
#
# the word pop is palendrom
#
# the word pup is palendrom
#
# the word rar is palendrom
#
# the word rarar is palendrom
#
# the word ror is palendrom
#
# the word roror is palendrom
#
# the word sas is palendrom
#
# the word sasas is palendrom
#
# the word sus is palendrom
#
# the word susus is palendrom
#
# the word tat is palendrom
#
# the word tattarrattat is palendrom
#
# the word eveeve is palendrom
#
# the word ekeeke is palendrom
#
# the word annaanna is palendrom
#
# the word hannah is palendrom
#
# the word ottootto is palendrom
#
# the word noonnoon is palendrom
#
# not
# not
# the word gigig is palendrom
#
# not
# the word peep is palendrom
#
# the word wowow is palendrom
#
# the word mumum is palendrom
