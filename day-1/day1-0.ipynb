# %% [markdown]
# <h1>DAY 1-0 PRINT<h1>

# %% [markdown]
# <h4><b>print is a function that prints something u put inside it<b><h4>

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# <h3><b>first exercise<h3><b>

# %%
print("Python Print Function\nThe function is declared like this:\nprint('what to print')")
# Out:
# Python Print Function
# The function is declared like this:
# print('what to print')

# %% [markdown]
# <h4><b>String manupulation<h4><b>

# %%
print("when we use backslash(\\) and (n) \nwe can break a line in print function\n-->\\n\n")
# Out:
# when we use backslash(\) and (n)
# we can break a line in print function
# -->\n

# %% [markdown]
# <b><h4>String Concatination<h4><b>

# %%
print("Hi,i'm"+" rud"+"ra")
# Out:
# Hi,i'm rudra

# %% [markdown]
# print(Day 1 - String Manipulation") <br>
# print("String Concatenation is done with the "+" sign.")<br>
#   print('e.g. print("Hello " + "world")')<br>
# print(("New lines can be created with a backslash and n.")
#
# DEBUGG THIS

# %%
print("Day 1 - String Manipulation")
print("String Concatenation is done with the '+' sign.")
print('e.g. print("Hello " + "world")')
print(("New lines can be created with a backslash and n."))
# Out:
# Day 1 - String Manipulation
# String Concatenation is done with the '+' sign.
# e.g. print("Hello " + "world")
# New lines can be created with a backslash and n.

# %% [markdown]
# <h2>INPUT FUNCTION<h2>

# %%
input("A promt for the user")
# Out:
# "i'm giving a prompt"

# %%
print("Hello "+input("what's your name?\n-->")+"!")
# Out:
# Hello rudra!

# %% [markdown]
# <h5>we can use the # to comment in our code<h5>

# %%
print("to comment multiple line first select all those\nline u want to comment and use the ctrl+/ ")
# Out:
# to comment multiple line first select all those
# line u want to comment and use the ctrl+/

# %% [markdown]
# <h4>INPUT EXERSIZE<h4>

# %% [markdown]
# print the number of charecter in a users name

# %%
#EASY WAY: using the len() function
#USED INPUT: rajdiprudra
print(f"your name has: {len(input("enter your name: "))} letters")
# Out:
# your name has: 11 letters

# %%
#HARD WAY: using the for loop 
#USED INPUT: rajdiprudra
user_name = input("enter your name: ")
count = 0
for i in user_name:
    count+=1
print(f"your name has: {count} letters")
# Out:
# your name has: 11 letters

# %% [markdown]
# <h3>PYTHON VARIABLE<h3>

# %%
name = 'raj'
print(name)
name = 'argho'
print(name)
name = 1234
print(name)

print("name" == "NaMe")
print("name" == "name")
# Out:
# raj
# argho
# 1234
# False
# True

# %% [markdown]
# <h4>AN EXERSIZE FOR THE VARIABLES<h4>

# %% [markdown]
# WE HAVE TO SWITCH THE VALUES OF THE VARIABLES<br> GIVEN a AND b TO ONE ANOTHER

# %%
a = "BAT"
b = "MAN"
print(a,b)

c = a
a = b
b = c

print(a,b)
# Out:
# BAT MAN
# MAN BAT

# %% [markdown]
# <h2>TODAY's FINAL PROJECT<h2>

# %% [markdown]
# <b>BAND NAME GENERATOR<b>

# %%
pet_name = input("enter the name of ur pet: ")
city_name = input("enter the name of ur city: ")
print(f"Your band-name is: {pet_name+"-"+city_name}")
# Out:
# Your band-name is: kuttarbaccha-magura
