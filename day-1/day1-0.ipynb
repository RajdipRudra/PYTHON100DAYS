# %% [markdown]
# DAY 1-0 PRINT

# %% [markdown]
# print is a function that prints something u put inside it

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# first exercise

# %%
print("Python Print Function\nThe function is declared like this:\nprint('what to print')")
# Out:
# Python Print Function
# The function is declared like this:
# print('what to print')
