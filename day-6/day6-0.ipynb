# %% [markdown]
# <h1>DAY-6<br>FUNCTIONS, <br> CODE BLOCKS AND WHILE LOOPS</h1>

# %% [markdown]
# <B> FUNCTION

# %%
def my_function():##defining the function
    print("hello")
    print("hi")

my_function()
# Out:
# hello
# hi

# %% [markdown]
# HURDEL-1

# %%
# def turn_right():
#     turn_left()
#     turn_left()
#     turn_left()

# def jump():
#     turn_left()
#     move()
#     turn_right()
#     move()
#     turn_right()
#     move()
#     turn_left()
    
# while at_goal()==False:
#     if (wall_in_front()==True):
#         jump()
#     elif front_is_clear()== True:
#         move()

# %% [markdown]
# Hurdle 4

# %%
# def turn_right():
#     turn_left()
#     turn_left()
#     turn_left()

# def jump():
#     while right_is_clear()==False:
#         turn_left()
#         if front_is_clear()== True:
#             move()
#     right_is_clear()==True:
#     turn_right()
#     move()
#     turn_right()

    
# while at_goal()==False:
#     if (wall_in_front()==True):
#         jump()
#     elif front_is_clear()== True:
#         move()

# %% [markdown]
# MAZEE

# %%
# def turn_right():
#     turn_left()
#     turn_left()
#     turn_left()

 
# while at_goal()==False:
#     if right_is_clear()== True :
#         turn_right()
#         move()
        
#     elif (wall_on_right()==True and front_is_clear()==True):
#         move()
        
#     elif wall_on_right()==True and wall_in_front()==True:
#         turn_left()
#     else:
#         move()
