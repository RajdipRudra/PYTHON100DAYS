# %% [markdown]
# <h1><b> DAY 10<br>FUNCTIONS WITH OUTPUTS

# %%
def formate_name(f_name,L_name):
    return f_name.title(),L_name.title()

formate_name("rajdip","rudra")
# Out:
# ('Rajdip', 'Rudra')

# %%
# year = int(input("enter ur year : "))


def is_leapyear(year):
    if year%4==0:
        if year%100==0:
            if year%400==0:
                return True
            else:
                return False
        else:
            return True
    else:
        return False

def days_in_month(year,month):
    days_in_month = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
    if is_leapyear(year=year) and month==1:
        return 29
    else:
        return days_in_month[month]




year = int(input("enter ur year : "))
month = int(input("enter a month: "))
dats = days_in_month(year,(month-1))
print(f"year: {year}")
print(f"mont: {month}")
print(dats)
# Out:
# year: 1900
# mont: 2
# 28

# %% [markdown]
# CALCULATOR

# %%
import art
logo_print = art.logo
print(logo_print)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 import art
# ----> 2 logo_print = art.logo
#       3 print(logo_print)
#
# AttributeError: module 'art' has no attribute 'logo'
