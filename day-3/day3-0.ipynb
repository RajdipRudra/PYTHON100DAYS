# %% [markdown]
# <h1>DAY 3 <br>CONDITIONAL STATEMENTS<br>LOGICAL OPERATORS<br>CODE BLOCKS AND SCOPE<h1>

# %% [markdown]
# <h3>CONDITIONAL STATEMENTS<h3>

# %% [markdown]
# <h4>if-else-elif<h4>

# %% [markdown]
#  BESIC SYNTAX--><br>
# <br>
#  if condition:<br>....do this<br>
#  else:<br>....do this

# %% [markdown]
# <h4>TICKET BOX EXERSIZR<h4>

# %%
print("welcome to rollercoaster!")
user_height = float(input("enter your height in cm :\n"))

if user_height>= 120:
    print("Here's your ticket sir. Enjoy ur ride!")
else:
    print("I'm sorry u can't ride the rollercoaster.")
# Out:
# welcome to rollercoaster!
# I'm sorry u can't ride the rollercoaster.

# %% [markdown]
# DAY 3.1 ODD OR EVEN EXERCISE

# %%
input_number =  float(input("enter a number -->"))
if input_number%2==0:
    print("EVEN")
else:
    print("ODD")
# Out:
# ODD

# %%
print("welcome to rollercoaster!")
user_height = float(input("enter your height in cm :\n"))
user_age = float(input("enter your age: "))

if user_height>= 120:
    if user_age>18:
        print(f"your ticket price is $12")
    elif user_age>12:
        print("your ticket price is $7")
    else:
        print("your ticket price is $5")
    
else:
    print("I'm sorry u can't ride the rollercoaster.")
# Out:
# welcome to rollercoaster!
# your ticket price is $12

# %% [markdown]
# <h4>BMI CALCULATOR UPGRADED<h4>

# %%
print("welcome to the bmi calculator")
user_height = float(input("enter ur height in meter: "))
user_weight = float(input("enter your weight in kg: "))

bmi = user_weight/user_height**2
bmi = round(bmi,2)

if bmi<=18.5:
    print(f"Your bmi is {bmi} and your underweight")
elif bmi<=25:
    print(f"Your bmi is {bmi} and your normal weight")
elif bmi<=30:
    print(f"Your bmi is {bmi} and your overweight")
elif bmi<=35:
    print(f"Your bmi is {bmi} and your obese")
else:
    print(f"Your bmi is {bmi} and your clinically obese")
# Out:
# welcome to the bmi calculator
# Your bmi is 24.91 and your normal weight

# %% [markdown]
# LEAP YEAR EXERSIZE

# %%
#year = int(input("Which year do your want to check? "))
years = [2019, 2020, 2016, 2011, 2024, 2017, 2000, 2013, 2023, 2012]


for year in years:
    if year%4==0:
        if year%100==0:
            if year%400==0:
                print(f"The year {year} is a leap year")
            else:
                print(f"The year {year} is-not a leap year")
        else:
            print(f"The year {year} is a leap year")
    else:
        print(f"The year {year} is-not a leap year")
# Out:
# The year 2019 is-not a leap year
# The year 2020 is a leap year
# The year 2016 is a leap year
# The year 2011 is-not a leap year
# The year 2024 is a leap year
# The year 2017 is-not a leap year
# The year 2000 is a leap year
# The year 2013 is-not a leap year
# The year 2023 is-not a leap year
# The year 2012 is a leap year

# %%
print("welcome to rollercoaster!")
user_height = float(input("enter your height in cm :\n"))
user_age = float(input("enter your age: "))
price = 0
if user_height>= 120:
    if user_age>18:
        price = 12
    elif user_age>12:
        price = 7
    else:
        price = 5

    photos = input("Do you want photos taken? ").lower()
    if photos=='y':
        price +=3
        print(f"your ticket price is ${price}")
    print(f"your ticket price is ${price}")
        
           
else:
    print("I'm sorry u can't ride the rollercoaster.")
# Out:
# welcome to rollercoaster!
# your ticket price is $8

# %% [markdown]
# PIZZA DELIVERIES

# %%
print("Welcome to Python Pizza Deliveries!")
size = input("What size do you want? s,m or l").lower()
add_pepperoni = input("Do you want pepperoni? y or n").lower()
extra_cheese = input("Do you want extra chesse? y or n").lower()

price = 0

if size=='s':
    price = 15
elif size=='m':
    price = 20
elif size=='l':
    price = 25

if add_pepperoni=='y':
    if size=='s':
        price+=2
    else:
        price+=3
if extra_cheese=='y':
    price+=1

print(f"Your final bill is: ${price}.")
# Out:
# Welcome to Python Pizza Deliveries!
# Your final bill is: $16.
